# %% [raw]
# !pip3 install yfinance mplfinance mpl_finance

# %%
from financial_market import *

# %%
df_concat, df_sector_dict, symbols = load_dataframe()
df_concat
# Out:
# /home/vanilla_skies/projects/financial_markets/my_project/financial_market.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date_first_added'][df.loc[df['symbol'] == "T"].index[0]] = "1983-11-30"
#     symbol                            security sec_filings  \
# 253    IPG  The Interpublic Group of Companies     reports
# 51       T                                AT&T     reports
# 470     VZ                             Verizon     reports
# 353    OMC                       Omnicom Group     reports
# 361   PARA                    Paramount Global     reports
# ..     ...                                 ...         ...
# 117    CMS                          CMS Energy     reports
# 11     AES                     AES Corporation     reports
# 98     CNP                  CenterPoint Energy     reports
# 378    PPL                     PPL Corporation     reports
# 167    EIX                Edison International     reports
#
#                 gics_sector                             gics_sub-industry  \
# 253  Communication Services                                   Advertising
# 51   Communication Services         Integrated Telecommunication Services
# 470  Communication Services         Integrated Telecommunication Services
# 353  Communication Services                                   Advertising
# 361  Communication Services                        Movies & Entertainment
# ..                      ...                                           ...
# 117               Utilities                               Multi-Utilities
# 11                Utilities  Independent Power Producers & Energy Traders
# 98                Utilities                               Multi-Utilities
# 378               Utilities                            Electric Utilities
# 167               Utilities                            Electric Utilities
#
#        headquarters_location date_first_added      cik      founded
# 253  New York City, New York       1992-10-01    51644  1961 (1930)
# 51             Dallas, Texas       1983-11-30   732717  1983 (1885)
# 470  New York City, New York       1983-11-30   732712  1983 (1877)
# 353  New York City, New York              NaN    29989         1986
# 361  New York City, New York              NaN   813828  2019 (1952)
# ..                       ...              ...      ...          ...
# 117        Jackson, Michigan       1999-05-03   811156         1886
# 11       Arlington, Virginia       1998-10-02   874761         1981
# 98            Houston, Texas       1985-07-31  1130310         1882
# 378  Allentown, Pennsylvania              NaN   922224         1920
# 167     Rosemead, California       1957-03-04   827052         1886
#
# [205 rows x 9 columns]

# %%
df_sector_dict
# Out:
# {'WHR': 'CD',
#  'MAR': 'CD',
#  'HD': 'CD',
#  'AZO': 'CD',
#  'GPC': 'CD',
#  'TJX': 'CD',
#  'DRI': 'CD',
#  'TGT': 'CD',
#  'F': 'CD',
#  'CCL': 'CD',
#  'VFC': 'CD',
#  'YUM': 'CD',
#  'BBWI': 'CD',
#  'LOW': 'CD',
#  'PHM': 'CD',
#  'HAS': 'CD',
#  'BBY': 'CD',
#  'NKE': 'CD',
#  'MCD': 'CD',
#  'NWL': 'CD',
#  'TPR': 'CD',
#  'CL': 'CS',
#  'WBA': 'CS',
#  'TAP': 'CS',
#  'ADM': 'CS',
#  'WMT': 'CS',
#  'KO': 'CS',
#  'HSY': 'CS',
#  'BF.B': 'CS',
#  'GIS': 'CS',
#  'CLX': 'CS',
#  'CAG': 'CS',
#  'SYY': 'CS',
#  'CPB': 'CS',
#  'COST': 'CS',
#  'PEP': 'CS',
#  'PG': 'CS',
#  'MO': 'CS',
#  'KMB': 'CS',
#  'KR': 'CS',
#  'K': 'CS',
#  'XOM': 'EG',
#  'COP': 'EG',
#  'MRO': 'EG',
#  'HES': 'EG',
#  'WMB': 'EG',
#  'APA': 'EG',
#  'HAL': 'EG',
#  'SLB': 'EG',
#  'CVX': 'EG',
#  'VLO': 'EG',
#  'OXY': 'EG',
#  'USB': 'FN',
#  'AIG': 'FN',
#  'RF': 'FN',
#  'CINF': 'FN',
#  'PGR': 'FN',
#  'TFC': 'FN',
#  'STT': 'FN',
#  'SCHW': 'FN',
#  'SPGI': 'FN',
#  'CMA': 'FN',
#  'COF': 'FN',
#  'TROW': 'FN',
#  'MS': 'FN',
#  'AFL': 'FN',
#  'MCO': 'FN',
#  'MET': 'FN',
#  'C': 'FN',
#  'HIG': 'FN',
#  'PNC': 'FN',
#  'L': 'FN',
#  'HBAN': 'FN',
#  'MMC': 'FN',
#  'BEN': 'FN',
#  'FITB': 'FN',
#  'GL': 'FN',
#  'AON': 'FN',
#  'BK': 'FN',
#  'JPM': 'FN',
#  'KEY': 'FN',
#  'ALL': 'FN',
#  'LNC': 'FN',
#  'NTRS': 'FN',
#  'WFC': 'FN',
#  'AXP': 'FN',
#  'BAC': 'FN',
#  'BSX': 'HC',
#  'PKI': 'HC',
#  'UNH': 'HC',
#  'MDT': 'HC',
#  'CI': 'HC',
#  'ABT': 'HC',
#  'WAT': 'HC',
#  'CVS': 'HC',
#  'BMY': 'HC',
#  'MRK': 'HC',
#  'PFE': 'HC',
#  'MCK': 'HC',
#  'CAH': 'HC',
#  'AMGN': 'HC',
#  'LLY': 'HC',
#  'BDX': 'HC',
#  'BAX': 'HC',
#  'JNJ': 'HC',
#  'DHR': 'HC',
#  'HUM': 'HC',
#  'LUV': 'ID',
#  'GE': 'ID',
#  'RTX': 'ID',
#  'ROK': 'ID',
#  'ETN': 'ID',
#  'WM': 'ID',
#  'EFX': 'ID',
#  'DOV': 'ID',
#  'CSX': 'ID',
#  'TXT': 'ID',
#  'PCAR': 'ID',
#  'FDX': 'ID',
#  'MAS': 'ID',
#  'GWW': 'ID',
#  'SWK': 'ID',
#  'SNA': 'ID',
#  'LMT': 'ID',
#  'BA': 'ID',
#  'EMR': 'ID',
#  'NOC': 'ID',
#  'CMI': 'ID',
#  'MMM': 'ID',
#  'HON': 'ID',
#  'UNP': 'ID',
#  'DE': 'ID',
#  'GD': 'ID',
#  'NSC': 'ID',
#  'CAT': 'ID',
#  'HWM': 'ID',
#  'PH': 'ID',
#  'ITW': 'ID',
#  'GLW': 'IT',
#  'TXN': 'IT',
#  'HPQ': 'IT',
#  'KLAC': 'IT',
#  'MSI': 'IT',
#  'AMD': 'IT',
#  'CTXS': 'IT',
#  'PAYX': 'IT',
#  'ADI': 'IT',
#  'NTAP': 'IT',
#  'QCOM': 'IT',
#  'CSCO': 'IT',
#  'MSFT': 'IT',
#  'ADBE': 'IT',
#  'MU': 'IT',
#  'AAPL': 'IT',
#  'AMAT': 'IT',
#  'ADP': 'IT',
#  'IBM': 'IT',
#  'INTC': 'IT',
#  'ADSK': 'IT',
#  'ORCL': 'IT',
#  'SEE': 'MT',
#  'EMN': 'MT',
#  'ECL': 'MT',
#  'PPG': 'MT',
#  'AVY': 'MT',
#  'WRK': 'MT',
#  'LIN': 'MT',
#  'APD': 'MT',
#  'FCX': 'MT',
#  'NUE': 'MT',
#  'NEM': 'MT',
#  'IFF': 'MT',
#  'BALL': 'MT',
#  'IP': 'MT',
#  'VMC': 'MT',
#  'SHW': 'MT',
#  'WY': 'RE',
#  'IPG': 'TC',
#  'T': 'TC',
#  'VZ': 'TC',
#  'OMC': 'TC',
#  'PARA': 'TC',
#  'LUMN': 'TC',
#  'DIS': 'TC',
#  'EXC': 'UT',
#  'DTE': 'UT',
#  'ETR': 'UT',
#  'SRE': 'UT',
#  'PEG': 'UT',
#  'NEE': 'UT',
#  'PNW': 'UT',
#  'SO': 'UT',
#  'AEP': 'UT',
#  'NI': 'UT',
#  'XEL': 'UT',
#  'FE': 'UT',
#  'D': 'UT',
#  'AEE': 'UT',
#  'ED': 'UT',
#  'DUK': 'UT',
#  'CMS': 'UT',
#  'AES': 'UT',
#  'CNP': 'UT',
#  'PPL': 'UT',
#  'EIX': 'UT'}

# %%
df, df_sector, df_both, not_done_for = get_closing_prices(symbols, df_sector_dict)
# Out:
# TPR not in past
# - BF.B: No data found for this date range, symbol may be delisted
# BF.B delisted
# MET not in past
# HWM not in past
# WRK not in past
# PARA not in past

# %%
# frame is in order
df_sector.columns.to_list()
# Out:
# ['date',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'CS',
#  'EG',
#  'EG',
#  'EG',
#  'EG',
#  'EG',
#  'EG',
#  'EG',
#  'EG',
#  'EG',
#  'EG',
#  'EG',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'FN',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'HC',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'ID',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'IT',
#  'MT',
#  'MT',
#  'MT',
#  'MT',
#  'MT',
#  'MT',
#  'MT',
#  'MT',
#  'MT',
#  'MT',
#  'MT',
#  'MT',
#  'MT',
#  'MT',
#  'MT',
#  'RE',
#  'TC',
#  'TC',
#  'TC',
#  'TC',
#  'TC',
#  'TC',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT',
#  'UT']

# %%
# these have become nan because symbols has values that aren't collected
print(df.isnull().values.any(), not_done_for)
# Out:
# False ['BF.B']

# %%
print(df.columns[df.isna().any()].tolist())
# Out:
# []

# %%
df.to_excel("output/sp500_stock_names.xlsx")
df_sector.to_excel("output/sp500_sector_names.xlsx")
df_both.to_excel("output/sp500_both.xlsx")

# %%
df.to_csv("output/sp500_stock_names.csv")
df_sector.to_csv("output/sp500_sector_names.csv")
df_both.to_csv("output/sp500_both.csv")

# %%
plot_candlesticks('AAPL')
# Out:
# [*********************100%***********************]  1 of 1 completed
# /home/vanilla_skies/.local/lib/python3.8/site-packages/mplfinance/_arg_validators.py:36: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
plt.plot(df["date"], df["AAPL"])
