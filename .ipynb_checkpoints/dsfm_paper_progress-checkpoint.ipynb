# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.special import (gamma, kv)
from scipy.stats import cramervonmises
from pandas_datareader import data as pdr
import yfinance as yf
import datetime
yf.pdr_override()

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("output_old/csv/sp500_stock_names.csv")
df.head()
# Out:
#    Unnamed: 0        date        WHR        MAR         HD      AZO  \
# 0           0  1999-12-31  36.483448  11.951112  43.704758  32.3125
# 1           1  2000-01-03  34.661022  11.548796  41.440063  30.5625
# 2           2  2000-01-04  33.329239  11.477802  39.254829  30.4375
# 3           3  2000-01-05  33.819897  11.667130  40.049461  30.3125
# 4           4  2000-01-06  34.100269  11.832785  38.142330  29.0625
#
#          GPC       TJX       DRI        TGT  ...        FE         D  \
# 0  11.794188  1.968308  6.568381  24.178312  ...  8.151894  7.874141
# 1  11.437691  1.956269  6.273940  23.725620  ...  7.927324  7.648447
# 2  11.318857  1.853941  6.228640  22.696753  ...  7.927324  7.836525
# 3  11.259440  1.799767  6.455132  22.182318  ...  8.219263  8.049676
# 4  11.259440  1.908116  6.387187  21.132877  ...  8.241718  8.137450
#
#          AEE         ED        DUK        CMS        AES       CNP       PPL  \
# 0  11.411933  11.974446  15.292458  15.532209  27.710835  6.736605  4.003064
# 1  11.259479  11.714136  14.720421  14.691791  26.876743  6.552540  3.882753
# 2  11.259479  11.865987  14.949243  14.878547  25.810934  6.626164  3.981191
# 3  11.695045  12.408306  15.559418  15.283185  26.088968  6.902254  4.068688
# 4  11.651489  12.429995  15.978907  15.158688  26.297491  6.939069  4.014003
#
#          EIX
# 0  13.493931
# 1  13.048775
# 2  13.178934
# 3  14.024991
# 4  13.992451
#
# [5 rows x 201 columns]

# %%
r = df.iloc[:, 2:]
r = np.asarray(r)
print(r.shape)
# Out:
# (5640, 199)

# %% [markdown]
# ## Volatility [FIGURE 1]

# %%
def get_stockdata(ticker,start,end):
    start = datetime.datetime(*list(map(int,start.split('/'))))
    end = datetime.datetime(*list(map(int,end.split('/'))))
    df = pdr.get_data_yahoo(ticker, start, end)
    return df

def plot_volatility(stock,ticker):
    df = stock.loc[:,['Close']]
    stock['returns'] = stock.Close.pct_change()
    stock['std'] = stock.returns.rolling(window=60, min_periods=1).std()
    stock = stock.iloc[2:,:]
    pos = {}
    stock['date'] = stock.index
    stock.index = np.arange(len(stock))
    stock.date = np.array(map(str,stock.date))
    for i in stock.index:
        if stock.date[i][:4] not in pos:
            pos[stock.date[i][:4]] = i
    
    plt.plot(stock.date,stock['std'])
    plt.xticks(ticks = list(pos.values())[::2],labels=list(pos.keys())[::2])
    plt.ylabel("Volatality")
    plt.title(ticker)
    plt.show()

goodyear = get_stockdata('GT','1992/01/01','2013/01/01')
plot_volatility(goodyear,'GT')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Correlation matrix [FIGURE 2]

# %%
def plot_corr_mats():
    data = pd.read_csv("output_old/csv/sp500_sector_names.csv")
    dates = list(data.date)
    newdates = [datetime.date(*(map(int,i.split('-')))) for i in dates]
    newdates[:5]
    data.date = newdates
    
    pos = {}
    i=0
    for col in data.columns[2:]:
        if col.split('.')[0] not in pos:
            pos[col.split('.')[0]] = i
        i+=1
    
    df2005 = data.query('date > datetime.date(2005,10,1) and date < datetime.date(2006,1,1)')
    for i in df2005.columns[2:]:
        df2005[i] = df2005[i].pct_change()
    
    df2006 = data.query('date > datetime.date(2006,1,1) and date < datetime.date(2006,4,1)')
    for i in df2006.columns[2:]:
        df2006[i] = df2006[i].pct_change()
    
    sns.heatmap(df2005.iloc[:,2:].corr(),cmap="Blues")
    plt.xticks(ticks=list(pos.values()),labels=list(pos.keys()))
    plt.yticks(ticks=list(pos.values()),labels=list(pos.keys()))
    plt.title("2005")
    plt.show()
    plt.figure()
    
    sns.heatmap(df2006.iloc[:,2:].corr(),cmap="Blues")
    plt.xticks(ticks=list(pos.values()),labels=list(pos.keys()))
    plt.yticks(ticks=list(pos.values()),labels=list(pos.keys()))
    plt.title("2006")
    plt.show()

plot_corr_mats()

# %% [markdown]
# ## Gaussian Distribution [FIGURE 3]
#
# https://github.com/juanhenao21/exact_distributions_financial/blob/main/project/distribution_tests/exact_multivariate_ampl_distributions_python.ipynb
#
# How is $r_l$ coming in page 2?

# %% [markdown]
# ## K-distribution [FIGURE 4]

# %% [markdown]
# ![formula_13.png](formula_13.png)
# ![](rot_and_scale.png)

# %%
def k_distribution(returns, N, alpha):
    """Computes the one dimensional K-distribution with parameters
    N and alpha
    """
    first_part = (
        (((np.sqrt(2)) ** (1 - N)) / (np.sqrt(np.pi) * gamma(N / 2)))
        * (np.sqrt(N / alpha)) ** (N / 2 + 0.5)
        * (np.abs(returns)) ** (N / 2 - 0.5)
    )
    second_part = kv(N / 2 - 0.5, np.abs(returns) * np.sqrt(N / alpha))
    dist = first_part * second_part
    return dist

def rotate_and_scale(returns):
    """Rotates the returns in the eigenbasis of the covariance matrix
    and normalizes them to standard deviation 1. The returns array must
    have a TxK dimension, and K must be smaller than T.
    """
    cov = returns.cov()
    eig_val, eig_vec = np.linalg.eig(cov)
    rot, scale = eig_vec, np.diag(1 / np.sqrt(eig_val))
    trans = rot.dot(scale)
    return returns.dot(trans)

# %%
df = pd.read_csv("output_old/csv/sp500_stock_names.csv")
df = df.iloc[:,2:]
for i in df.columns:
    df[i] = df[i].pct_change()
df = df.iloc[1:,:]
# normalization of dataframe
# df = (df - df.mean()) / df.std()

# %%
def plot_rolled(df, delta_t):
    df_rolled  = df.rolling(window=delta_t, min_periods=1).sum()
    rr = np.arange(-8, 9, 0.11)
    bessel = k_distribution(rr, 4, 1)
    rot_returns = rotate_and_scale(df_rolled)
    print(rot_returns.shape, rot_returns[0].std())
    one_col = []
    for col in rot_returns.columns:
        one_col.append(rot_returns[col])
    agg = pd.concat(one_col, ignore_index=True)
    agg.plot(
        kind="density",
        figsize=(16, 9),
        logy=True,
        label="Aggregated returns",
        legend=True,
        lw=2,
    )
    plt.plot(rr, bessel, "o", label="K-distribution")
    plt.legend(fontsize=25)
    plt.xlim(-10, 10)
    plt.ylim(10 ** -4, 1)
    plt.xlabel(r"$\tilde{r}$", fontsize=20)
    plt.ylabel("PDF", fontsize=20)
    plt.grid(True)

# %%
plot_rolled(df, delta_t = 1)
# Out:
# (5639, 199) 0.9999999999999998

# %%
plot_rolled(df, delta_t = 20)
# Out:
# (5639, 199) 0.9999999999999994

# %% [markdown]
# ![](figure_4.png)

# %%
def cramer_test(df, delta_t):
    df_rolled  = df.rolling(window=delta_t, min_periods=1).sum()
    rot_returns = rotate_and_scale(df_rolled)
    # print(rot_returns.shape, rot_returns[0].std())
    one_col = []
    for col in rot_returns.columns:
        one_col.append(rot_returns[col])
    # agg = pd.concat(one_col, ignore_index=True)
    agg = rot_returns.sum(axis=1)
    # agg = rot_returns.std(axis=1)
    return int(cramervonmises(agg, 'norm').statistic - 350)

# %%
cramer_values = []
for i in range(1, 31):
    cramer_values.append(cramer_test(df, i))

# %%
plt.scatter(list(range(1, 30)), np.asarray(cramer_values[:-1]))
